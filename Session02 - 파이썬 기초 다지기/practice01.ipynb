# %%
a=3.2
type(a)
# Out:
# float

# %%
strValue = "10"
intValue = 3

# %%
answer = int(strValue)+intValue

# %%
answer
# Out:
# 13

# %%
yearWeekValue = "2017w42"
yearWeekValue[0:4]
# Out:
# '2017'

# %%
# 라이브러리 불러오기
import pandas as pd

# 데이터 불러오기
customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
customerTotalList = customerData["TOTAL_AMOUNT"].tolist()

# 중복값 제거
customerTotalList = list(set(customerTotalList))

# 최대값, 최소값 선정
maxValue = max(customerTotalList)
minValue = min(customerTotalList)

# 최대값, 최소값 제거
customerTotalList.remove(maxValue)
customerTotalList.remove(minValue)

# 평균 산출
average =  sum(customerTotalList) / len(customerTotalList)

# 출력
print(average)
# Out:
# 213252.27912211593

# %%
import pandas as pd

customerData = pd.read_csv("../dataset/kopo_customerdata.csv")
customerTotalList = customerData["TOTAL_AMOUNT"].tolist()
# customerTotalList.sort()
customerTotalList = list(set(customerTotalList))
customerTotalList
# Out:
# [0,
#  409600,
#  204800,
#  1024000,
#  106500,
#  8200,
#  213000,
#  417800,
#  114700,
#  16400,
#  221200,
#  835600,
#  122900,
#  24600,
#  434200,
#  131100,
#  32800,
#  139300,
#  344100,
#  41000,
#  147500,
#  49200,
#  254000,
#  155700,
#  360500,
#  57400,
#  163900,
#  368700,
#  65600,
#  172100,
#  73800,
#  180300,
#  385100,
#  82000,
#  2441300,
#  188500,
#  90200,
#  196700,
#  98400,
#  303200,
#  409700,
#  204900,
#  106600,
#  311400,
#  8300,
#  417900,
#  213100,
#  114800,
#  319600,
#  16500,
#  221300,
#  123000,
#  327800,
#  532600,
#  24700,
#  229500,
#  434300,
#  336000,
#  131200,
#  32900,
#  237700,
#  139400,
#  41100,
#  450700,
#  147600,
#  352400,
#  49300,
#  663700,
#  155800,
#  360600,
#  57500,
#  164000,
#  778400,
#  65700,
#  680100,
#  172200,
#  377000,
#  73900,
#  278700,
#  180400,
#  82100,
#  188600,
#  90300,
#  196800,
#  98500,
#  205000,
#  409800,
#  106700,
#  311500,
#  8400,
#  213200,
#  319700,
#  114900,
#  16600,
#  221400,
#  123100,
#  24800,
#  229600,
#  131300,
#  33000,
#  237800,
#  139500,
#  41200,
#  246000,
#  147700,
#  352500,
#  49400,
#  254200,
#  155900,
#  565500,
#  57600,
#  164100,
#  65800,
#  475400,
#  172300,
#  377100,
#  74000,
#  278800,
#  180500,
#  82200,
#  188700,
#  90400,
#  295200,
#  196900,
#  98600,
#  303400,
#  508200,
#  205100,
#  409900,
#  106800,
#  721200,
#  311600,
#  8500,
#  213300,
#  115000,
#  16700,
#  123200,
#  942400,
#  328000,
#  24900,
#  229700,
#  434500,
#  131400,
#  33100,
#  237900,
#  139600,
#  41300,
#  246100,
#  352600,
#  147800,
#  49500,
#  254300,
#  360800,
#  156000,
#  57700,
#  262500,
#  164200,
#  573800,
#  65900,
#  680300,
#  172400,
#  377200,
#  74100,
#  278900,
#  180600,
#  82300,
#  491900,
#  287100,
#  188800,
#  393600,
#  90500,
#  197000,
#  98700,
#  205200,
#  106900,
#  8600,
#  115100,
#  319900,
#  1753500,
#  729500,
#  16800,
#  221600,
#  123300,
#  25000,
#  229800,
#  131500,
#  33200,
#  238000,
#  139700,
#  41400,
#  451000,
#  147900,
#  352700,
#  49600,
#  156100,
#  57800,
#  262600,
#  164300,
#  573900,
#  66000,
#  270800,
#  172500,
#  74200,
#  279000,
#  180700,
#  385500,
#  82400,
#  188900,
#  393700,
#  90600,
#  197100,
#  606700,
#  1016300,
#  98800,
#  205300,
#  107000,
#  721400,
#  213500,
#  8700,
#  623100,
#  418300,
#  115200,
#  320000,
#  16900,
#  123400,
#  328200,
#  25100,
#  229900,
#  639500,
#  131600,
#  33300,
#  238100,
#  139800,
#  41500,
#  246300,
#  352800,
#  148000,
#  49700,
#  254500,
#  459300,
#  664100,
#  156200,
#  57900,
#  262700,
#  369200,
#  164400,
#  66100,
#  270900,
#  172600,
#  582200,
#  74300,
#  279100,
#  688700,
#  180800,
#  82500,
#  287300,
#  189000,
#  393800,
#  90700,
#  197200,
#  402000,
#  98900,
#  303700,
#  600,
#  205400,
#  107100,
#  8800,
#  213600,
#  115300,
#  320100,
#  17000,
#  221800,
#  328300,
#  123500,
#  533100,
#  25200,
#  230000,
#  336500,
#  131700,
#  33400,
#  238200,
#  139900,
#  41600,
#  246400,
#  451200,
#  148100,
#  49800,
#  459400,
#  156300,
#  58000,
#  262800,
#  1491600,
#  164500,
#  369300,
#  66200,
#  271000,
#  172700,
#  787100,
#  74400,
#  180900,
#  82600,
#  189100,
#  393900,
#  90800,
#  197300,
#  99000,
#  700,
#  205500,
#  312000,
#  107200,
#  8900,
#  213700,
#  115400,
#  320200,
#  17100,
#  221900,
#  426700,
#  123600,
#  25300,
#  131800,
#  336600,
#  33500,
#  238300,
#  140000,
#  41700,
#  246500,
#  148200,
#  557800,
#  49900,
#  156400,
#  361200,
#  58100,
#  467700,
#  262900,
#  164600,
#  369400,
#  66300,
#  271100,
#  172800,
#  74500,
#  279300,
#  181000,
#  590600,
#  1409800,
#  385800,
#  82700,
#  287500,
#  394000,
#  189200,
#  90900,
#  705300,
#  197400,
#  99100,
#  508700,
#  303900,
#  800,
#  205600,
#  107300,
#  312100,
#  418600,
#  9000,
#  213800,
#  115500,
#  17200,
#  426800,
#  222000,
#  123700,
#  25400,
#  230200,
#  131900,
#  33600,
#  238400,
#  443200,
#  140100,
#  41800,
#  246600,
#  148300,
#  557900,
#  50000,
#  156500,
#  361300,
#  1385300,
#  58200,
#  263000,
#  164700,
#  369500,
#  66400,
#  271200,
#  172900,
#  74600,
#  279400,
#  181100,
#  385900,
#  82800,
#  803700,
#  91000,
#  295800,
#  197500,
#  99200,
#  304000,
#  205700,
#  410500,
#  900,
#  107400,
#  312200,
#  517000,
#  9100,
#  213900,
#  115600,
#  17300,
#  222100,
#  123800,
#  25500,
#  230300,
#  132000,
#  336800,
#  541600,
#  33700,
#  238500,
#  549800,
#  140200,
#  41900,
#  246700,
#  148400,
#  353200,
#  50100,
#  254900,
#  156600,
#  361400,
#  58300,
#  164800,
#  66500,
#  173000,
#  74700,
#  386000,
#  181200,
#  590800,
#  82900,
#  287700,
#  91100,
#  197600,
#  402400,
#  99300,
#  304100,
#  205800,
#  1000,
#  107500,
#  312300,
#  9200,
#  214000,
#  623600,
#  115700,
#  320500,
#  17400,
#  222200,
#  123900,
#  328700,
#  25600,
#  230400,
#  132100,
#  336900,
#  33800,
#  238600,
#  140300,
#  42000,
#  246800,
#  353300,
#  148500,
#  558100,
#  50200,
#  255000,
#  156700,
#  361500,
#  58400,
#  369700,
#  164900,
#  66600,
#  271400,
#  377900,
#  173100,
#  74800,
#  279600,
#  484400,
#  795700,
#  181300,
#  83000,
#  287800,
#  189500,
#  91200,
#  296000,
#  197700,
#  99400,
#  205900,
#  410700,
#  1100,
#  107600,
#  312400,
#  418900,
#  9300,
#  214100,
#  115800,
#  525400,
#  320600,
#  17500,
#  222300,
#  427100,
#  124000,
#  25700,
#  230500,
#  132200,
#  337000,
#  33900,
#  238700,
#  140400,
#  42100,
#  246900,
#  148600,
#  353400,
#  50300,
#  255100,
#  156800,
#  58500,
#  165000,
#  66700,
#  271500,
#  173200,
#  74900,
#  279700,
#  181400,
#  83100,
#  189600,
#  599200,
#  91300,
#  296100,
#  500900,
#  197800,
#  99500,
#  304300,
#  206000,
#  1200,
#  107700,
#  312500,
#  9400,
#  214200,
#  115900,
#  935100,
#  525500,
#  17600,
#  222400,
#  124100,
#  328900,
#  25800,
#  230600,
#  132300,
#  34000,
#  238800,
#  140500,
#  345300,
#  42200,
#  247000,
#  148700,
#  50400,
#  255200,
#  156900,
#  58600,
#  165100,
#  66800,
#  173300,
#  378100,
#  75000,
#  484600,
#  279800,
#  386300,
#  591100,
#  83200,
#  288000,
#  189700,
#  91400,
#  197900,
#  99600,
#  1300,
#  206100,
#  107800,
#  312600,
#  9500,
#  214300,
#  116000,
#  17700,
#  427300,
#  222500,
#  124200,
#  25900,
#  230700,
#  337200,
#  132400,
#  34100,
#  238900,
#  443700,
#  140600,
#  42300,
#  148800,
#  50500,
#  255300,
#  460100,
#  157000,
#  58700,
#  468300,
#  263500,
#  165200,
#  66900,
#  271700,
#  173400,
#  75100,
#  484700,
#  181600,
#  83300,
#  902500,
#  288100,
#  189800,
#  91500,
#  198000,
#  99700,
#  509300,
#  1400,
#  206200,
#  107900,
#  312700,
#  9600,
#  214400,
#  116100,
#  525700,
#  17800,
#  222600,
#  124300,
#  329100,
#  26000,
#  230800,
#  132500,
#  34200,
#  239000,
#  140700,
#  42400,
#  353700,
#  148900,
#  50600,
#  255400,
#  460200,
#  157100,
#  58800,
#  263600,
#  165300,
#  67000,
#  173500,
#  75200,
#  280000,
#  181700,
#  386500,
#  83400,
#  288200,
#  697800,
#  189900,
#  394700,
#  91600,
#  296400,
#  198100,
#  402900,
#  99800,
#  304600,
#  1500,
#  820700,
#  206300,
#  108000,
#  312800,
#  9700,
#  214500,
#  116200,
#  321000,
#  17900,
#  222700,
#  329200,
#  124400,
#  26100,
#  640500,
#  435700,
#  132600,
#  337400,
#  34300,
#  239100,
#  140800,
#  42500,
#  247300,
#  149000,
#  50700,
#  255500,
#  157200,
#  58900,
#  263700,
#  165400,
#  67100,
#  271900,
#  173600,
#  75300,
#  181800,
#  386600,
#  288300,
#  83500,
#  190000,
#  394800,
#  91700,
#  198200,
#  607800,
#  714300,
#  99900,
#  206400,
#  1600,
#  108100,
#  9800,
#  214600,
#  116300,
#  321100,
#  18000,
#  427600,
#  222800,
#  124500,
#  534100,
#  26200,
#  231000,
#  132700,
#  34400,
#  239200,
#  140900,
#  42600,
#  247400,
#  149100,
#  353900,
#  50800,
#  255600,
#  157300,
#  59000,
#  263800,
#  165500,
#  370300,
#  67200,
#  272000,
#  173700,
#  75400,
#  280200,
#  181900,
#  83600,
#  288400,
#  493200,
#  190100,
#  91800,
#  198300,
#  100000,
#  304800,
#  1700,
#  411300,
#  206500,
#  108200,
#  313000,
#  9900,
#  214700,
#  116400,
#  18100,
#  222900,
#  124600,
#  26300,
#  231100,
#  132800,
#  34500,
#  648900,
#  239300,
#  141000,
#  42700,
#  149200,
#  50900,
#  255700,
#  157400,
#  59100,
#  165600,
#  370400,
#  67300,
#  476900,
#  173800,
#  378600,
#  75500,
#  280300,
#  182000,
#  386800,
#  288500,
#  83700,
#  190200,
#  395000,
#  91900,
#  296700,
#  198400,
#  100100,
#  1800,
#  206600,
#  411400,
#  108300,
#  313100,
#  10000,
#  214800,
#  116500,
#  321300,
#  526100,
#  18200,
#  223000,
#  124700,
#  534300,
#  26400,
#  231200,
#  132900,
#  337700,
#  542500,
#  34600,
#  239400,
#  141100,
#  345900,
#  42800,
#  149300,
#  51000,
#  255800,
#  157500,
#  362300,
#  59200,
#  264000,
#  165700,
#  370500,
#  67400,
#  272200,
#  173900,
#  75600,
#  182100,
#  83800,
#  288600,
#  493400,
#  190300,
#  92000,
#  296800,
#  198500,
#  608100,
#  100200,
#  206700,
#  1900,
#  108400,
#  10100,
#  214900,
#  116600,
#  18300,
#  427900,
#  124800,
#  26500,
#  231300,
#  436100,
#  133000,
#  337800,
#  34700,
#  239500,
#  141200,
#  346000,
#  42900,
#  247700,
#  149400,
#  354200,
#  51100,
#  255900,
#  157600,
#  59300,
#  468900,
#  165800,
#  67500,
#  174000,
#  378800,
#  75700,
#  182200,
#  387000,
#  83900,
#  288700,
#  493500,
#  190400,
#  92100,
#  198600,
#  100300,
#  509900,
#  2000,
#  206800,
#  108500,
#  313300,
#  10200,
#  419800,
#  215000,
#  321500,
#  116700,
#  18400,
#  223200,
#  124900,
#  26600,
#  231400,
#  133100,
#  34800,
#  239600,
#  141300,
#  43000,
#  149500,
#  51200,
#  256000,
#  157700,
#  59400,
#  264200,
#  165900,
#  67600,
#  272400,
#  174100,
#  75800,
#  280600,
#  182300,
#  84000,
#  288800,
#  190500,
#  92200,
#  198700,
#  100400,
#  2100,
#  206900,
#  108600,
#  313400,
#  10300,
#  215100,
#  116800,
#  18500,
#  125000,
#  739400,
#  26700,
#  231500,
#  436300,
#  133200,
#  34900,
#  444500,
#  239700,
#  141400,
#  43100,
#  247900,
#  149600,
#  51300,
#  256100,
#  157800,
#  362600,
#  59500,
#  166000,
#  67700,
#  272500,
#  174200,
#  75900,
#  182400,
#  387200,
#  84100,
#  493700,
#  288900,
#  395400,
#  190600,
#  92300,
#  1321100,
#  198800,
#  100500,
#  2200,
#  207000,
#  411800,
#  108700,
#  313500,
#  10400,
#  215200,
#  116900,
#  18600,
#  223400,
#  125100,
#  534700,
#  26800,
#  231600,
#  133300,
#  542900,
#  35000,
#  239800,
#  141500,
#  43200,
#  248000,
#  149700,
#  354500,
#  51400,
#  256200,
#  157900,
#  59600,
#  469200,
#  166100,
#  370900,
#  67800,
#  272600,
#  174300,
#  ...]
