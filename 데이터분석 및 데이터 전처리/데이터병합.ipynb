# %% [markdown]
# # 1. 라이브러리 선언

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. 데이터 불러오기

# %%
joinMaster = pd.read_csv("../stddev/dataset/join_region_master.csv", encoding="ms949")
joinSellout = pd.read_csv("../stddev/dataset/join_kopo_product_volume.csv")

# %%
joinMaster
# Out:
#   REGIONID REGIONNAME
# 0      A01         한국
# 1      A02         미국
# 2      A03        프랑스
# 3      A04         독일

# %%
joinSellout
# Out:
#   REGIONID PRODUCT  YEARWEEK   QTY
# 0      A01  ST0001    201901  3000
# 1      A01  ST0001    201902  3500
# 2      A02  ST0002    201901  4000
# 3      A02  ST0003    201902  7000

# %%
joinMaster2 = joinMaster.rename(columns={"REGIONID":"AP2ID"}, inplace=True)

# %%
joinMaster2

# %% [markdown]
# # 3. 데이터 병합

# %%
pd.merge(left = joinSellout, 
         right = joinMaster2, 
         left_on = "REGIONID", 
         right_on = "AP2ID",
         how = "right")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-cd48ca4fa6f2> in <module>
# ----> 1 pd.merge(left = joinSellout,
#       2          right = joinMaster2,
#       3          left_on = "REGIONID",
#       4          right_on = "AP2ID",
#       5          how = "right")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     570     ):
#     571         _left = _validate_operand(left)
# --> 572         _right = _validate_operand(right)
#     573         self.left = self.orig_left = _left
#     574         self.right = self.orig_right = _right
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2004             return obj.to_frame()
#    2005     else:
# -> 2006         raise TypeError(
#    2007             "Can only merge Series or DataFrame objects, "
#    2008             "a {obj} was passed".format(obj=type(obj))
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'NoneType'> was passed

# %%
joinMaster.loc[4, "REGIONID"] = "A05"
joinMaster
# Out:
#   REGIONID REGIONNAME
# 0      A01         한국
# 1      A02         미국
# 2      A03        프랑스
# 3      A04         독일
# 4      A05        NaN

# %%
joinMaster.loc[4, "REGIONNAME"] = "인도"
joinMaster
# Out:
#   REGIONID REGIONNAME
# 0      A01         한국
# 1      A02         미국
# 2      A03        프랑스
# 3      A04         독일
# 4      A05         인도

# %%
joinMaster.rename(columns={"REGIONID":"AP2ID"}, inplace=True)
joinMaster
# Out:
#   AP2ID REGIONNAME
# 0   A01         한국
# 1   A02         미국
# 2   A03        프랑스
# 3   A04         독일

# %%
pd.merge(left = joinSellout, 
         right = joinMaster, 
         left_on = "REGIONID",
         right_on="AP2ID",
         how="outer")
# Out:
#   REGIONID PRODUCT  YEARWEEK     QTY AP2ID REGIONNAME
# 0      A01  ST0001  201901.0  3000.0   A01         한국
# 1      A01  ST0001  201902.0  3500.0   A01         한국
# 2      A02  ST0002  201901.0  4000.0   A02         미국
# 3      A02  ST0003  201902.0  7000.0   A02         미국
# 4      NaN     NaN       NaN     NaN   A03        프랑스
# 5      NaN     NaN       NaN     NaN   A04         독일

# %%
joinMaster2 = joinMaster.loc[joinMaster.AP2ID=="A01"]
joinMaster2
# Out:
#   AP2ID REGIONNAME
# 0   A01         한국

# %% [markdown]
# # 심화학습

# %%
columnList = ["REGIONID","PRODUCT","DATE","QTY"]

# %%
data1 = pd.DataFrame(
[["서울","AA카드", 20210518, 100],
["서울","AA카드", 20210517, 200],
["서울","AA카드", 20210516, 300],
["서울","AA카드", 20210515, 400],
["서울","AA카드", 20210514, 500]
], columns=columnList)

data1
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    AA카드  20210518  100
# 1       서울    AA카드  20210517  200
# 2       서울    AA카드  20210516  300
# 3       서울    AA카드  20210515  400
# 4       서울    AA카드  20210514  500

# %%
data2 = data1.copy()
data2.PRODUCT= "BB카드"
data2
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    BB카드  20210518  100
# 1       서울    BB카드  20210517  200
# 2       서울    BB카드  20210516  300
# 3       서울    BB카드  20210515  400
# 4       서울    BB카드  20210514  500

# %%
data3 = data2.copy()
data3.REGIONID = "부산"
data3
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       부산    BB카드  20210518  100
# 1       부산    BB카드  20210517  200
# 2       부산    BB카드  20210516  300
# 3       부산    BB카드  20210515  400
# 4       부산    BB카드  20210514  500

# %%
data4 = data3.copy()
data4.PRODUCT= "CC카드"
data4
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       부산    CC카드  20210518  100
# 1       부산    CC카드  20210517  200
# 2       부산    CC카드  20210516  300
# 3       부산    CC카드  20210515  400
# 4       부산    CC카드  20210514  500

# %%
mergedData = data1.append(data2).append(data3).append(data4)

# %%
mergedData
# Out:
#   REGIONID PRODUCT      DATE  QTY
# 0       서울    AA카드  20210518  100
# 1       서울    AA카드  20210517  200
# 2       서울    AA카드  20210516  300
# 3       서울    AA카드  20210515  400
# 4       서울    AA카드  20210514  500
# 0       서울    BB카드  20210518  100
# 1       서울    BB카드  20210517  200
# 2       서울    BB카드  20210516  300
# 3       서울    BB카드  20210515  400
# 4       서울    BB카드  20210514  500
# 0       부산    BB카드  20210518  100
# 1       부산    BB카드  20210517  200
# 2       부산    BB카드  20210516  300
# 3       부산    BB카드  20210515  400
# 4       부산    BB카드  20210514  500
# 0       부산    CC카드  20210518  100
# 1       부산    CC카드  20210517  200
# 2       부산    CC카드  20210516  300
# 3       부산    CC카드  20210515  400
# 4       부산    CC카드  20210514  500

# %% [markdown]
# ## 프로모션 정보

# %%
promotionColumns = ["SUBSIDIARY","CARD_NAME","PROMOTION_NAME","PROMOTION_RATE"]

# %%
promotionData = pd.DataFrame([
    ["서울","AA카드", "서울_프로모션", 0.5],
    ["부산","BB카드", "부산_프로모션", 0.3],
    ["부산","CC카드", "부산_프로모션", 0.25]
    ], columns=promotionColumns)

# %%
promotionData
# Out:
#   SUBSIDIARY CARD_NAME PROMOTION_NAME  PROMOTION_RATE
# 0         서울      AA카드        서울_프로모션            0.50
# 1         부산      BB카드        부산_프로모션            0.30
# 2         부산      CC카드        부산_프로모션            0.25

# %%
pd.merge(left = mergedData, 
         right = promotionData, 
         left_on = ["REGIONID", "PRODUCT"],
         right_on = ["SUBSIDIARY", "CARD_NAME"],
         how="outer")

# outer 합집합 -> 할인 안 된 곳도 출력
# inner 교집합 -> 할인된 곳만 출력
# Out:
#    REGIONID PRODUCT      DATE  QTY SUBSIDIARY CARD_NAME PROMOTION_NAME  \
# 0        서울    AA카드  20210518  100         서울      AA카드        서울_프로모션
# 1        서울    AA카드  20210517  200         서울      AA카드        서울_프로모션
# 2        서울    AA카드  20210516  300         서울      AA카드        서울_프로모션
# 3        서울    AA카드  20210515  400         서울      AA카드        서울_프로모션
# 4        서울    AA카드  20210514  500         서울      AA카드        서울_프로모션
# 5        서울    BB카드  20210518  100        NaN       NaN            NaN
# 6        서울    BB카드  20210517  200        NaN       NaN            NaN
# 7        서울    BB카드  20210516  300        NaN       NaN            NaN
# 8        서울    BB카드  20210515  400        NaN       NaN            NaN
# 9        서울    BB카드  20210514  500        NaN       NaN            NaN
# 10       부산    BB카드  20210518  100         부산      BB카드        부산_프로모션
# 11       부산    BB카드  20210517  200         부산      BB카드        부산_프로모션
# 12       부산    BB카드  20210516  300         부산      BB카드        부산_프로모션
# 13       부산    BB카드  20210515  400         부산      BB카드        부산_프로모션
# 14       부산    BB카드  20210514  500         부산      BB카드        부산_프로모션
# 15       부산    CC카드  20210518  100         부산      CC카드        부산_프로모션
# 16       부산    CC카드  20210517  200         부산      CC카드        부산_프로모션
# 17       부산    CC카드  20210516  300         부산      CC카드        부산_프로모션
# 18       부산    CC카드  20210515  400         부산      CC카드        부산_프로모션
# 19       부산    CC카드  20210514  500         부산      CC카드        부산_프로모션
#
#     PROMOTION_RATE
# 0             0.50
# 1             0.50
# 2             0.50
# 3             0.50
# 4             0.50
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10            0.30
# 11            0.30
# 12            0.30
# 13            0.30
# 14            0.30
# 15            0.25
# 16            0.25
# 17            0.25
# 18            0.25
# 19            0.25
